# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pip install reliability
# Out:
# ...
#   Using cached reliability-0.8.1-py3-none-any.whl (246 kB)
# ...
#   Using cached autograd-1.3-py3-none-any.whl
# ...
#   Using cached mplcursors-0.5.1-py3-none-any.whl
# ...
#   Using cached autograd_gamma-0.5.0-py3-none-any.whl
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from reliability.Fitters import Fit_Weibull_2P

# %%
failures = [1430, 3044, 4414, 6148, 8036, 8370, 8645, 10868]
censored = [11000] * 5

# %%
from reliability.Fitters import Fit_Weibull_2P

# %%
wb = Fit_Weibull_2P(failures=failures, right_censored=censored)
plt.show()
# Out:
# Results from Fit_Weibull_2P (95% CI):
# Analysis method: Maximum Likelihood Estimation (MLE)
# Optimizer: TNC
# Failures / Right censored: 8/5 (38.46154% right censored)
#
# Parameter  Point Estimate  Standard Error  Lower CI  Upper CI
#     Alpha         11427.3         2410.73   7557.41   17278.9
#      Beta         1.73462        0.558186  0.923199   3.25922
#
# Goodness of fit    Value
#  Log-likelihood -82.7257
#            AICc  170.651
#             BIC  170.581
#              AD  36.8895

# %%
from reliability.Fitters import Fit_Lognormal_2P

# %%
#Define failures & censored(survival) data. Try different ways to see the impact of data input to the results
failures = [1430, 3044, 4414, 6148, 8036, 8370, 8645, 10868]
censored = [11000] * 5

# %%
wb = Fit_Lognormal_2P(failures=failures, right_censored=censored)
plt.show()
# Out:
# Results from Fit_Lognormal_2P (95% CI):
# Analysis method: Maximum Likelihood Estimation (MLE)
# Optimizer: TNC
# Failures / Right censored: 8/5 (38.46154% right censored)
#
# Parameter  Point Estimate  Standard Error  Lower CI  Upper CI
#        Mu         9.11379        0.271857   8.58096   9.64662
#     Sigma        0.875409        0.236057  0.516038   1.48505
#
# Goodness of fit    Value
#  Log-likelihood -82.9742
#            AICc  171.148
#             BIC  171.078
#              AD  36.9307

# %%
failures = [1005, 1430, 1461, 2498, 2587, 3013, 3044, 4201, 4414, 6148, 6331, 6485, 6908, 7154, 7488, 8036, 8370, 8584, 8614, 8645, 10745, 10868]
censored = [1186, 1917, 3347, 4442, 4748, 5753, 6514, 7670]

# %%
from reliability.Fitters import Fit_Weibull_2P

# %%
wb = Fit_Weibull_2P(failures=failures, right_censored=censored)
plt.show()
# Out:
# Results from Fit_Weibull_2P (95% CI):
# Analysis method: Maximum Likelihood Estimation (MLE)
# Optimizer: TNC
# Failures / Right censored: 22/8 (26.66667% right censored)
#
# Parameter  Point Estimate  Standard Error  Lower CI  Upper CI
#     Alpha         7204.71         701.612   5952.84   8719.84
#      Beta         2.19942        0.383695   1.56248   3.09602
#
# Goodness of fit    Value
#  Log-likelihood -210.661
#            AICc  425.766
#             BIC  428.124
#              AD  1.74023

# %%
failures = [1005, 1430, 1461, 2498, 2587, 3013, 3044, 4201, 4414, 6148, 6331, 6485, 6908, 7154, 7488, 8036, 8370, 8584, 8614, 8645, 10745, 10868]
censored = [1186, 1917, 3347, 4442, 4748, 5753, 6514, 7670]

# %%
from reliability.Fitters import Fit_Lognormal_2P
wb = Fit_Lognormal_2P(failures=failures, right_censored=censored)
plt.show()
# Out:
# Results from Fit_Lognormal_2P (95% CI):
# Analysis method: Maximum Likelihood Estimation (MLE)
# Optimizer: TNC
# Failures / Right censored: 22/8 (26.66667% right censored)
#
# Parameter  Point Estimate  Standard Error  Lower CI  Upper CI
#        Mu         8.62924        0.138092   8.35859    8.8999
#     Sigma        0.694673        0.104147  0.517805  0.931954
#
# Goodness of fit    Value
#  Log-likelihood -213.935
#            AICc  432.314
#             BIC  434.672
#              AD  2.04268

# %%
failures = [1430, 2587, 3013, 4201, 4414, 6148, 6908, 7154, 8036, 8370]
censored = [1186, 1917, 3347, 4442, 4748, 5753, 6514, 7670, 11000, 11000, 11000, 11000, 11000, 11000, 11000, 11000, 11000, 11000, 11000, 11000, 11000, 11000]

# %%
from reliability.Fitters import Fit_Weibull_2P

# %%
wb = Fit_Weibull_2P(failures=failures, right_censored=censored)
plt.show()
# Out:
# Results from Fit_Weibull_2P (95% CI):
# Analysis method: Maximum Likelihood Estimation (MLE)
# Optimizer: TNC
# Failures / Right censored: 10/22 (68.75% right censored)
#
# Parameter  Point Estimate  Standard Error  Lower CI  Upper CI
#     Alpha         17658.6         5045.73   10086.4   30915.5
#      Beta         1.45553        0.410194  0.837794   2.52874
#
# Goodness of fit    Value
#  Log-likelihood -110.166
#            AICc  224.745
#             BIC  227.263
#              AD  105.308

# %%
failures = [1005, 1186, 1917, 3347, 4442, 4748, 5753, 6514, 7670, 1430, 1461, 2498, 2587, 3013, 3044, 4201, 4414, 6148, 6331, 6485, 6908, 7154, 7488, 8036, 8370, 8584, 8614, 8645, 10745, 10868]

# %%
wb = Fit_Weibull_2P(failures=failures)
plt.show()
# Out:
# Results from Fit_Weibull_2P (95% CI):
# Analysis method: Maximum Likelihood Estimation (MLE)
# Optimizer: TNC
# Failures / Right censored: 30/0 (0% right censored)
#
# Parameter  Point Estimate  Standard Error  Lower CI  Upper CI
#     Alpha         6151.93         585.261   5105.43   7412.93
#      Beta         2.01452        0.304286   1.49831   2.70859
#
# Goodness of fit    Value
#  Log-likelihood -280.003
#            AICc   564.45
#             BIC  566.808
#              AD 0.953147

# %% [markdown]
# ## fit_everything (Determines best fit method)

# %%
from reliability.Fitters import Fit_Everything

# %%
failures = [1005, 1430, 1461, 2498, 2587, 3013, 3044, 4201, 4414, 6148, 6331, 6485, 6908, 7154, 7488, 8036, 8370, 8584, 8614, 8645, 10745, 10868]
censored = [1186, 1917, 3347, 4442, 4748, 5753, 6514, 7670]

# %%
Fit_Everything(failures=failures, right_censored=censored, show_histogram_plot=False, show_probability_plot=False, show_PP_plot=False, show_best_distribution_probability_plot=True)
# Out:
# Results from Fit_Everything:
# Analysis method: MLE
# Failures / Right censored: 22/8 (26.66667% right censored)
#
#    Distribution   Alpha    Beta Gamma Alpha 1  Beta 1 Alpha 2  Beta 2 Proportion 1 DS      Mu    Sigma      Lambda  Log-likelihood    AICc     BIC      AD optimizer
#      Weibull_2P 7204.71 2.19942                                                                                           -210.661 425.766 428.124 1.74023       TNC
#       Normal_2P                                                                       6363.45  2966.62                    -210.827 426.099 428.457 1.58632       TNC
#       Gumbel_2P                                                                       7731.74  2455.33                    -210.866 426.177 428.535 1.50748       TNC
#      Weibull_CR                       10212.8 1.43407 9393.96 6.49335                                                     -208.191 425.983 429.987 1.44153    powell
# ...
